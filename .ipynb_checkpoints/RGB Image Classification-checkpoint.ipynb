png',
#  'latamSatData/datasetRGB_relabel/Train/Open Evergreen Broad Leaf Forest/79_tile_153065.png',
#  'latamSatData/datasetRGB_relabel/Train/Open Evergreen Broad Leaf Forest/75_tile_144358.png',
#  'latamSatData/datasetRGB_relabel/Train/Open Evergreen Broad Leaf Forest/4_tile_8146.png',
#  'latamSatData/datasetRGB_relabel/Train/Open Evergreen Broad Leaf Forest/100_tile_192083.png',
#  'latamSatData/datasetRGB_relabel/Train/Open Evergreen Broad Leaf Forest/75_tile_144428.png',
#  'latamSatData/datasetRGB_relabel/Train/Open Evergreen Broad Leaf Forest/46_tile_92234.png',
#  'latamSatData/datasetRGB_relabel/Train/Open Evergreen Broad Leaf Forest/81_tile_156526.png',
#  'latamSatData/datasetRGB_relabel/Train/Open Evergreen Broad Leaf Forest/133_tile_254190.png',
#  'latamSatData/datasetRGB_relabel/Train/Open Evergreen Broad Leaf Forest/61_tile_116832.png',
#  'latamSatData/datasetRGB_relabel/Train/Open Evergreen Broad Leaf Forest/36_tile_71197.png',
#  'latamSatData/datasetRGB_relabel/Train/Open Evergreen Broad Leaf Forest/73_tile_140217.png',
#  'latamSatData/datasetRGB_relabel/Train/Open Evergreen Broad Leaf Forest/107_tile_202410.png',
#  ...]

# %%
classDictionary = {30: 'Herbaceous Vegetation',
20: 'Shrubs',
40: 'Agricultural Land',
50: 'Urban Areas',
60: 'Bare Earth/Sparse Vegetation',
70: 'Snow and Ice',
80: 'Permanent Water Bodies',
90: 'Herbaceous Wetland',
100: 'Moss and Lichen',
111: 'Closed Evergreen Needle Leaf Forest',
112: 'Closed Evergreen Broad Leaf Forest',
113: 'Closed Deciduous Needle Leaft Forest',
114: 'Closed Deciduous Broad Leaf Forest',
115: 'Closed Mixed Forest',
116: 'Other Closed Forest',
121: 'Open Evergreen Needle Leaf Forest',
122: 'Open Evergreen Broad Leaf Forest',
123: 'Open Deciduous Needle Leaft Forest',
124: 'Open Deciduous Broad Leaf Forest',
125: 'Open Mixed Forest',
126: 'Other Open Forest',
200: 'Oceans, Seas'}

#for idx, fs in enumerate(fileStrings):
  #  parts = fs.split('/')
  #  ecoregionCode = parts[-3]
  #  filename = ecoregionCode + '_' + parts[-1] 
  #  parts[-1] = filename
  #  parts[1] = topFolder
  #  parts.pop(2)
  #  className = classDictionary[int(parts[-2])]
  #  parts[-2] = className
 #   newFile = '/'.join(parts)
 #   newDir = '/'.join(parts[:-1])
#    if not os.path.exists(n#ewDir):
#        os.makedirs(newDir)#

#    shutil.copy(fs, newFile)
#    if idx % 1000 == 0 :
#        print(idx, 'done')

# %%
classes = glob.glob('latamSatData/datasetRGB_relabel/*/*')
classes = [c.split('/')[-1] for c in classes]
idxKeys = [i for i in range(len(classes))]

# %%
classnameDict = dict(zip(idxKeys, classes))

# %%
classnameDict
# Out:
# {0: 'Open Evergreen Broad Leaf Forest',
#  1: 'Bare Earth Sparse Vegetation',
#  2: 'Permanent Water Bodies',
#  3: 'Closed Deciduous Broad Leaf Forest',
#  4: 'Open Mixed Forest',
#  5: 'Urban Areas',
#  6: 'Snow and Ice',
#  7: 'Oceans, Seas',
#  8: 'Closed Evergreen Needle Leaf Forest',
#  9: 'Agricultural Land',
#  10: 'Other Closed Forest',
#  11: 'Open Evergreen Needle Leaf Forest',
#  12: 'Shrubs',
#  13: 'Other Open Forest',
#  14: 'Closed Mixed Forest',
#  15: 'Open Deciduous Broad Leaf Forest',
#  16: 'Closed Evergreen Broad Leaf Forest',
#  17: 'Herbaceous Vegetation',
#  18: 'Herbaceous Wetland'}

# %%
builder = tfds.folder_dataset.ImageFolder(folder)
base_dataset = builder.as_dataset()['all']
filenames = []
labels = []
def onehot_encode(x):
    x['label'] = tf.one_hot(x['label'], 19)
    return x
base_dataset = base_dataset.map(onehot_encode)
base_dataset = base_dataset.shuffle(base_dataset.cardinality())
base_dataset = base_dataset.batch(32)

# %%
def train_test_split_(dataset, test_size):
    dataset = dataset.shuffle(dataset.cardinality())
    pct_size = dataset.cardinality().numpy() / 100 
    test_size = round(pct_size * test_size)
    test_dataset = dataset.take(test_size)
    train_dataset = dataset.skip(test_size)
    return train_dataset, test_dataset

# %%
train, test = train_test_split_(base_dataset, 20)

# %%
def make_model(input_shape, num_classes):
    inputs = tf.keras.Input(shape=input_shape)

    # Entry block
    x = tf.keras.layers.Rescaling(1.0 / 255)(inputs)
    x = tf.keras.layers.Conv2D(128, 3, strides=2, padding="same")(inputs)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation("relu")(x)

    previous_block_activation = x  # Set aside residual

    for size in [256, 512, 768]:
        x = tf.keras.layers.Activation("relu")(x)
        x = tf.keras.layers.SeparableConv2D(size, 3, padding="same")(x)
        x = tf.keras.layers.BatchNormalization()(x)

        x = tf.keras.layers.Activation("relu")(x)
        x = tf.keras.layers.SeparableConv2D(size, 3, padding="same")(x)
        x = tf.keras.layers.BatchNormalization()(x)

        x = tf.keras.layers.MaxPooling2D(3, strides=2, padding="same")(x)

        # Project residual
        residual = tf.keras.layers.Conv2D(size, 1, strides=2, padding="same")(
            previous_block_activation
        )
        x = tf.keras.layers.add([x, residual])  # Add back residual
        previous_block_activation = x  # Set aside next residual

    x = tf.keras.layers.SeparableConv2D(1024, 3, padding="same")(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation("relu")(x)

    x = tf.keras.layers.GlobalAveragePooling2D()(x)
    if num_classes == 2:
        activation = "sigmoid"
        units = 1
    else:
        activation = "softmax"
        units = num_classes

    x = tf.keras.layers.Dropout(0.5)(x)
    outputs = tf.keras.layers.Dense(units, activation=activation)(x)
    return tf.keras.Model(inputs, outputs)


m = make_model(input_shape=(64,64,3), num_classes=19)
# Out:
# 2023-10-24 13:33:02.953162: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M2 Pro
# 2023-10-24 13:33:02.953186: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2023-10-24 13:33:02.953191: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.33 GB
# 2023-10-24 13:33:02.953611: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:303] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-10-24 13:33:02.953852: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:269] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath="rgb_logscale_cleanlab_classification",
    save_weights_only=False,
    monitor='val_accuracy',
    mode='max',
    save_best_only=True)

# %%
m.compile(
    loss="categorical_crossentropy",
    optimizer="adam",
    metrics=["accuracy"],
    run_eagerly=False
)

# %%
train_history = m.fit(train, epochs=36, validation_data=test, callbacks=[model_checkpoint_callback])

# %%
break

# %%
feature_extraction = tf.keras.Model(m.input, m.layers[-3].output)

# %%
class_to_int_dict = dict(zip(classnameDict.values(), classnameDict.keys()))
class_to_int_dict
# Out:
# {'Open Evergreen Broad Leaf Forest': 0,
#  'Bare Earth Sparse Vegetation': 1,
#  'Permanent Water Bodies': 2,
#  'Closed Deciduous Broad Leaf Forest': 3,
#  'Open Mixed Forest': 4,
#  'Urban Areas': 5,
#  'Snow and Ice': 6,
#  'Oceans, Seas': 7,
#  'Closed Evergreen Needle Leaf Forest': 8,
#  'Agricultural Land': 9,
#  'Other Closed Forest': 10,
#  'Open Evergreen Needle Leaf Forest': 11,
#  'Shrubs': 12,
#  'Other Open Forest': 13,
#  'Closed Mixed Forest': 14,
#  'Open Deciduous Broad Leaf Forest': 15,
#  'Closed Evergreen Broad Leaf Forest': 16,
#  'Herbaceous Vegetation': 17,
#  'Herbaceous Wetland': 18}

# %%
from cleanlab import Datalab

# %%
from PIL import Image
import numpy as np

# %%
import numpy as np
import pandas as pd

# %%
issues_list = []
labs_list = []
filepaths = []
i = 1
for batch in base_dataset:
    print('batch', i)
    images = batch['image'].numpy()
    classes = batch['label'].numpy()
    paths = batch['image/filename']
    filepaths.append(paths)
    classProb = m.predict(images, verbose=0)
    predFeat= feature_extraction.predict(images, verbose=0)
    data_to_clean = {'Images':np.squeeze(np.array(images)), 'Labels':np.argmax(classes, axis=1)}
    lab = Datalab(data=data_to_clean, label_name="Labels", image_key="Images")
    lab.find_issues(pred_probs=np.squeeze(np.array(classProb)), features=np.squeeze(np.array(predFeat)))
    issues = lab.get_issues('label')
    issues['filepath'] = paths
    issues_list.append(issues)
    labs_list.append(lab)
    i += 1
# Out:
# batch 1
# Finding label issues ...
# Finding outlier issues ...
# Fitting OOD estimator based on provided features ...
# Finding near_duplicate issues ...
# Finding non_iid issues ...
# Finding dark, light, low_information, odd_aspect_ratio, odd_size, grayscale, blurry images ...
#   0%|          | 0/145257 [00:17<?, ?it/s]
# Error in checking for image issues: 'list' object has no attribute 'entropy'
#
# Audit complete. 34123 issues found in the dataset.
# batch 2
# Finding label issues ...
# Finding outlier issues ...
# Fitting OOD estimator based on provided features ...
# Finding near_duplicate issues ...
# Finding non_iid issues ...
# Finding dark, light, low_information, odd_aspect_ratio, odd_size, grayscale, blurry images ...
#   0%|          | 0/153600 [00:00<?, ?it/s]
# Error in checking for image issues: 'list' object has no attribute 'entropy'
#
# Audit complete. 36179 issues found in the dataset.

# %%
all_issues = pd.concat(issues_list)
# Out:
#   Cell In[29], line 2
#     break
#     ^
# SyntaxError: 'break' outside loop

# %%
all_issues
all_issues['given_label'] = all_issues['given_label'].map(classnameDict)
all_issues['predicted_label'] = all_issues['predicted_label'].map(classnameDict)
# Out:
#         is_label_issue  label_score                          given_label  \
# 0                 True     0.002927   Closed Evergreen Broad Leaf Forest
# 1                False     0.177570                         Snow and Ice
# 2                False     0.751860     Open Evergreen Broad Leaf Forest
# 3                False     0.999999                   Herbaceous Wetland
# 4                False     0.999606   Closed Deciduous Broad Leaf Forest
# ...                ...          ...                                  ...
# 153595           False     0.597584                    Other Open Forest
# 153596            True     0.154792                  Closed Mixed Forest
# 153597            True     0.054911                    Other Open Forest
# 153598           False     0.999996     Open Deciduous Broad Leaf Forest
# 153599            True     0.030261  Closed Evergreen Needle Leaf Forest
#
#                            predicted_label  \
# 0        Open Evergreen Needle Leaf Forest
# 1         Open Deciduous Broad Leaf Forest
# 2         Open Evergreen Broad Leaf Forest
# 3                       Herbaceous Wetland
# 4       Closed Deciduous Broad Leaf Forest
# ...                                    ...
# 153595                   Other Open Forest
# 153596              Permanent Water Bodies
# 153597                 Other Closed Forest
# 153598    Open Deciduous Broad Leaf Forest
# 153599                        Snow and Ice
#
#                                                  filepath
# 0       b'latamSatData/datasetRGB_relabel/Train/Shrubs...
# 1       b'latamSatData/datasetRGB_relabel/Train/Herbac...
# 2       b'latamSatData/datasetRGB_relabel/Train/Agricu...
# 3       b'latamSatData/datasetRGB_relabel/Train/Urban ...
# 4       b'latamSatData/datasetRGB_relabel/Train/Closed...
# ...                                                   ...
# 153595  b'latamSatData/datasetRGB_relabel/Train/Other ...
# 153596  b'latamSatData/datasetRGB_relabel/Train/Other ...
# 153597  b'latamSatData/datasetRGB_relabel/Train/Other ...
# 153598  b'latamSatData/datasetRGB_relabel/Train/Perman...
# 153599  b'latamSatData/datasetRGB_relabel/Train/Oceans...
#
# [298857 rows x 5 columns]

# %%
all_issues['filepath'] = all_issues['filepath'].apply(lambda x: x.decode())

# %%
all_issues[all_issues['is_label_issue']]

def relabel_filepath(file_path, new_label):
    file_path = file_path.split('/')
    file_path[-2]=new_label
    file_path = '/'.join(file_path)
    return file_path
all_issues['new_filepath'] = all_issues.apply(lambda x: relabel_filepath(x.filepath, x.predicted_label), axis=1)

# %%
def move_file(old_path, new_path):
    shutil.move(old_path, new_path)

# %%
all_issues
# Out:
#         is_label_issue  label_score                          given_label  \
# 0                 True     0.002927   Closed Evergreen Broad Leaf Forest
# 1                False     0.177570                         Snow and Ice
# 2                False     0.751860     Open Evergreen Broad Leaf Forest
# 3                False     0.999999                   Herbaceous Wetland
# 4                False     0.999606   Closed Deciduous Broad Leaf Forest
# ...                ...          ...                                  ...
# 153595           False     0.597584                    Other Open Forest
# 153596            True     0.154792                  Closed Mixed Forest
# 153597            True     0.054911                    Other Open Forest
# 153598           False     0.999996     Open Deciduous Broad Leaf Forest
# 153599            True     0.030261  Closed Evergreen Needle Leaf Forest
#
#                            predicted_label  \
# 0        Open Evergreen Needle Leaf Forest
# 1         Open Deciduous Broad Leaf Forest
# 2         Open Evergreen Broad Leaf Forest
# 3                       Herbaceous Wetland
# 4       Closed Deciduous Broad Leaf Forest
# ...                                    ...
# 153595                   Other Open Forest
# 153596              Permanent Water Bodies
# 153597                 Other Closed Forest
# 153598    Open Deciduous Broad Leaf Forest
# 153599                        Snow and Ice
#
#                                                  filepath  \
# 0       latamSatData/datasetRGB_relabel/Train/Shrubs/1...
# 1       latamSatData/datasetRGB_relabel/Train/Herbaceo...
# 2       latamSatData/datasetRGB_relabel/Train/Agricult...
# 3       latamSatData/datasetRGB_relabel/Train/Urban Ar...
# 4       latamSatData/datasetRGB_relabel/Train/Closed E...
# ...                                                   ...
# 153595  latamSatData/datasetRGB_relabel/Train/Other Cl...
# 153596  latamSatData/datasetRGB_relabel/Train/Other Op...
# 153597  latamSatData/datasetRGB_relabel/Train/Other Cl...
# 153598  latamSatData/datasetRGB_relabel/Train/Permanen...
# 153599  latamSatData/datasetRGB_relabel/Train/Oceans, ...
#
#                                              new_filepath
# 0       latamSatData/datasetRGB_relabel/Train/Open Eve...
# 1       latamSatData/datasetRGB_relabel/Train/Open Dec...
# 2       latamSatData/datasetRGB_relabel/Train/Open Eve...
# 3       latamSatData/datasetRGB_relabel/Train/Herbaceo...
# 4       latamSatData/datasetRGB_relabel/Train/Closed D...
# ...                                                   ...
# 153595  latamSatData/datasetRGB_relabel/Train/Other Op...
# 153596  latamSatData/datasetRGB_relabel/Train/Permanen...
# 153597  latamSatData/datasetRGB_relabel/Train/Other Cl...
# 153598  latamSatData/datasetRGB_relabel/Train/Open Dec...
# 153599  latamSatData/datasetRGB_relabel/Train/Snow and...
#
# [298857 rows x 6 columns]

# %%
# Out:
#         is_label_issue  label_score                          given_label  \
# 0                 True     0.002927   Closed Evergreen Broad Leaf Forest
# 7                 True     0.054241   Closed Deciduous Broad Leaf Forest
# 10                True     0.045215                         Snow and Ice
# 11                True     0.210110    Open Evergreen Needle Leaf Forest
# 13                True     0.142389     Open Evergreen Broad Leaf Forest
# ...                ...          ...                                  ...
# 153574            True     0.000137                    Agricultural Land
# 153592            True     0.002771                    Other Open Forest
# 153596            True     0.154792                  Closed Mixed Forest
# 153597            True     0.054911                    Other Open Forest
# 153599            True     0.030261  Closed Evergreen Needle Leaf Forest
#
#                           predicted_label  \
# 0       Open Evergreen Needle Leaf Forest
# 7                            Snow and Ice
# 10       Open Evergreen Broad Leaf Forest
# 11                      Open Mixed Forest
# 13                    Closed Mixed Forest
# ...                                   ...
# 153574                       Snow and Ice
# 153592                       Snow and Ice
# 153596             Permanent Water Bodies
# 153597                Other Closed Forest
# 153599                       Snow and Ice
#
#                                                  filepath  \
# 0       latamSatData/datasetRGB_relabel/Train/Shrubs/1...
# 7       latamSatData/datasetRGB_relabel/Train/Closed E...
# 10      latamSatData/datasetRGB_relabel/Train/Herbaceo...
# 11      latamSatData/datasetRGB_relabel/Train/Open Eve...
# 13      latamSatData/datasetRGB_relabel/Train/Agricult...
# ...                                                   ...
# 153574  latamSatData/datasetRGB_relabel/Train/Open Dec...
# 153592  latamSatData/datasetRGB_relabel/Train/Other Cl...
# 153596  latamSatData/datasetRGB_relabel/Train/Other Op...
# 153597  latamSatData/datasetRGB_relabel/Train/Other Cl...
# 153599  latamSatData/datasetRGB_relabel/Train/Oceans, ...
#
#                                              new_filepath
# 0       latamSatData/datasetRGB_relabel/Train/Open Eve...
# 7       latamSatData/datasetRGB_relabel/Train/Snow and...
# 10      latamSatData/datasetRGB_relabel/Train/Open Eve...
# 11      latamSatData/datasetRGB_relabel/Train/Open Mix...
# 13      latamSatData/datasetRGB_relabel/Train/Closed M...
# ...                                                   ...
# 153574  latamSatData/datasetRGB_relabel/Train/Snow and...
# 153592  latamSatData/datasetRGB_relabel/Train/Snow and...
# 153596  latamSatData/datasetRGB_relabel/Train/Permanen...
# 153597  latamSatData/datasetRGB_relabel/Train/Other Cl...
# 153599  latamSatData/datasetRGB_relabel/Train/Snow and...
#
# [58256 rows x 6 columns]

# %%
all_issues
# Out:
#         is_label_issue  label_score                          given_label  \
# 0                 True     0.002927   Closed Evergreen Broad Leaf Forest
# 1                False     0.177570                         Snow and Ice
# 2                False     0.751860     Open Evergreen Broad Leaf Forest
# 3                False     0.999999                   Herbaceous Wetland
# 4                False     0.999606   Closed Deciduous Broad Leaf Forest
# ...                ...          ...                                  ...
# 153595           False     0.597584                    Other Open Forest
# 153596            True     0.154792                  Closed Mixed Forest
# 153597            True     0.054911                    Other Open Forest
# 153598           False     0.999996     Open Deciduous Broad Leaf Forest
# 153599            True     0.030261  Closed Evergreen Needle Leaf Forest
#
#                            predicted_label  \
# 0        Open Evergreen Needle Leaf Forest
# 1         Open Deciduous Broad Leaf Forest
# 2         Open Evergreen Broad Leaf Forest
# 3                       Herbaceous Wetland
# 4       Closed Deciduous Broad Leaf Forest
# ...                                    ...
# 153595                   Other Open Forest
# 153596              Permanent Water Bodies
# 153597                 Other Closed Forest
# 153598    Open Deciduous Broad Leaf Forest
# 153599                        Snow and Ice
#
#                                                  filepath  \
# 0       latamSatData/datasetRGB_relabel/Train/Shrubs/1...
# 1       latamSatData/datasetRGB_relabel/Train/Herbaceo...
# 2       latamSatData/datasetRGB_relabel/Train/Agricult...
# 3       latamSatData/datasetRGB_relabel/Train/Urban Ar...
# 4       latamSatData/datasetRGB_relabel/Train/Closed E...
# ...                                                   ...
# 153595  latamSatData/datasetRGB_relabel/Train/Other Cl...
# 153596  latamSatData/datasetRGB_relabel/Train/Other Op...
# 153597  latamSatData/datasetRGB_relabel/Train/Other Cl...
# 153598  latamSatData/datasetRGB_relabel/Train/Permanen...
# 153599  latamSatData/datasetRGB_relabel/Train/Oceans, ...
#
#                                              new_filepath
# 0       latamSatData/datasetRGB_relabel/Train/Open Eve...
# 1       latamSatData/datasetRGB_relabel/Train/Open Dec...
# 2       latamSatData/datasetRGB_relabel/Train/Open Eve...
# 3       latamSatData/datasetRGB_relabel/Train/Herbaceo...
# 4       latamSatData/datasetRGB_relabel/Train/Closed D...
# ...                                                   ...
# 153595  latamSatData/datasetRGB_relabel/Train/Other Op...
# 153596  latamSatData/datasetRGB_relabel/Train/Permanen...
# 153597  latamSatData/datasetRGB_relabel/Train/Other Cl...
# 153598  latamSatData/datasetRGB_relabel/Train/Open Dec...
# 153599  latamSatData/datasetRGB_relabel/Train/Snow and...
#
# [298857 rows x 6 columns]

# %%
all_issues.to_csv('relabel_1.csv')

# %%
def relabel_images(filepaths, issues,

# %%
issues_list = []
for i in range(len(labs_list)):
    label_issues = labs_list[i].get_issues("label")
    label_issues = label_issues[label_issues['is_label_issue']]
    label_issues['given_label'] = label_issues['given_label'].map(classnameDict)
    label_issues['predicted_label'] = label_issues['predicted_label'].map(classnameDict)
    issues_list.append(label_issues)
label_issues = pd.concat(issues_list)

# %%
label_issues.columns

# %%
import pandas as pd

# %%
adj

# %%
label_issues = all_issues[all_issues['is_label_issue']]
adj = pd.crosstab(label_issues['given_label'], label_issues['predicted_label'])

# %%
plt.figure(figsize=(10,10))
plt.imshow(adj)
plt.xticks(range(len(adj.columns)), adj.columns,rotation='vertical')
plt.ylabel('Given Label')
plt.xlabel('New Label')
plt.yticks(range(len(adj.index)), adj.index)
plt.colorbar()
plt.show()

# %%
issues = label_issues[label_issues['is_label_issue']]

# %%
issues['given_label']
