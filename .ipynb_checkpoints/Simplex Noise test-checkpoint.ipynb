# %%
# !pip install opensimplex==0.3
# Out:
# Collecting opensimplex==0.3
#   Downloading opensimplex-0.3-py3-none-any.whl (15 kB)
# Installing collected packages: opensimplex
#   Attempting uninstall: opensimplex
#     Found existing installation: opensimplex 0.4.5
#     Uninstalling opensimplex-0.4.5:
#       Successfully uninstalled opensimplex-0.4.5
# Successfully installed opensimplex-0.3

# %%
from opensimplex import OpenSimplex
import random
import numpy as np
import matplotlib.pyplot as plt

# %%
simplex = OpenSimplex(1)

# %%
# Out:
# Help on OpenSimplex in module opensimplex.api object:
#
# class OpenSimplex(builtins.object)
#  |  OpenSimplex(seed: int) -> None
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, seed: int) -> None
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  get_seed(self) -> int
#  |
#  |  noise2(self, x: float, y: float) -> float
#  |
#  |  noise2array(self, x: numpy.ndarray, y: numpy.ndarray) -> numpy.ndarray
#  |
#  |  noise3(self, x: float, y: float, z: float) -> float
#  |
#  |  noise3array(self, x: numpy.ndarray, y: numpy.ndarray, z: numpy.ndarray) -> numpy.ndarray
#  |
#  |  noise4(self, x: float, y: float, z: float, w: float) -> float
#  |
#  |  noise4array(self, x: numpy.ndarray, y: numpy.ndarray, z: numpy.ndarray, w: numpy.ndarray) -> numpy.ndarray
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
def create_noise(h, w, seed=2, FEATURE_SIZE=40, freq_sine = 8):
    
    size = w
    j = 0

    opensimplex.seed(seed)

    array = np.zeros([h,w])
    for y in range(h):
        for x in range(w):
            array[x, y] = opensimplex.noise4(x=x/FEATURE_SIZE, y=y/FEATURE_SIZE, z=0.0, w=0.0)
            
    array = np.sin(array * freq_sine * np.pi)
    return array

# %%
def perturb(image, noise, budget):
    noise = np.sign((noise - 0.5) * 2) * budget
    noise = np.clip(noise, np.maximum(-img, -budget), np.minimum(255 - img, budget))

# %%
noise = create_noise(64,64, freq_sine=24)

# %%
plt.imshow(noise)
